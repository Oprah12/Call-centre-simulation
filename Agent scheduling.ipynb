# %% [markdown]
# #pip install scipy

# %%
import numpy as np
import pandas as pd
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# %% [markdown]
# ### **Experiment 1: Agent scheduling**

# %%
random.seed(50)
# Constants
start_time = datetime(2023, 1, 1, 8, 0)
end_time = datetime(2023, 4, 1, 16, 0)
NUMBER_OF_CUSTOMERS = 500
NUMBER_OF_AGENTS = 20

# Base lambda values
lambda_base_weekday = 224/8/NUMBER_OF_CUSTOMERS
lambda_base_weekend = 100/8/NUMBER_OF_CUSTOMERS

# Define customer and agent attributes
customers = [{'id': i+1,
              'lambda_weekday_morning': lambda_base_weekday + np.random.exponential(scale=0.0001),
              'lambda_weekday_afternoon': lambda_base_weekday + np.random.exponential(scale=0.0001),
              'lambda_weekend_morning': lambda_base_weekend + np.random.exponential(scale=0.00001),
              'lambda_weekend_afternoon': lambda_base_weekend + np.random.exponential(scale=0.00001),
              'tolerance': timedelta(minutes=np.random.uniform(2, 8)),
              'next_possible_call_time': start_time} for i in range(NUMBER_OF_CUSTOMERS)]



def truncated_exponential_with_outlier_inverse(lambda_scale, min_val=3*60, max_val=13*60, outlier_val=25*60, outlier_prob=0.05):
    # Check for the chance of an outlier
    if np.random.random() < outlier_prob:
        return outlier_val
    
    # CDF values for the truncation limits
    cdf_min = 1 - np.exp(-min_val / lambda_scale)
    cdf_max = 1 - np.exp(-max_val / lambda_scale)
    
    # Generate a random number between cdf_min and cdf_max
    u = np.random.uniform(cdf_min, cdf_max)
    
    # Apply the inverse CDF to get the sampled value
    sampled_value = -lambda_scale * np.log(1 - u)
    
    return sampled_value


# Function to simulate call generation using a nonhomogeneous Poisson process (NHPP)
def simulate_calls_for_customer_nhpp(customer, start_time, end_time, high_volume_period):
    calls = []
    while True:
        if high_volume_period == "morning":
            if 8 <= start_time.hour < 12:
                lambda_val = 0.6 * (customer['lambda_weekday_morning'] if start_time.weekday() < 6 else customer['lambda_weekend_morning'])
            else:
                lambda_val = 0.4 * (customer['lambda_weekday_afternoon'] if start_time.weekday() < 6 else customer['lambda_weekend_afternoon'])
        elif high_volume_period == "afternoon":
            if 8 <= start_time.hour < 12:
                lambda_val = 0.6 * (customer['lambda_weekday_afternoon'] if start_time.weekday() < 6 else customer['lambda_weekend_afternoon'])
               # lambda_val = 0.4 * (customer['lambda_weekday_morning'] if start_time.weekday() < 6 else customer['lambda_weekend_morning'])
            else:
               # lambda_val = 0.6 * (customer['lambda_weekday_afternoon'] if start_time.weekday() < 6 else customer['lambda_weekend_afternoon'])
                lambda_val = 0.4 * (customer['lambda_weekday_morning'] if start_time.weekday() < 6 else customer['lambda_weekend_morning'])
                
        next_call_time = start_time + timedelta(hours=np.random.exponential(1 / lambda_val))
        if next_call_time <= end_time:
            calls.append({'customer_id': customer['id'], 'call_time': next_call_time, 'tolerance': customer['tolerance']})
            start_time = next_call_time
        else:
            break
    return calls



# Optimized simulation function
def optimized_simulation(run, high_volume_period, agents_split):
    # Initialize lists to store call logs, answered calls, and wait times
    call_logs, answered_calls, wait_times = [], [], []
    # List to store average wait times for each day
    daily_avg_wait_times = []
    # Start time for the simulation
    current_time = start_time

    # Initialize agents for the morning shift based on the agents' split configuration
    agents_morning = [{'id': i+1, 
                       # Set agent responsiveness, higher for peak times if agent split indicates a high volume period in the morning
                       'responsiveness': min(1, 0.97 + np.random.exponential(scale=0.01)) if agents_split == [5,15] else min(1, 0.93 + np.random.exponential(scale=0.01)),   
                       'available_until': start_time,  # When the agent becomes available (start of the day)
                       'talk_duration_lambda': 5*60}  # Average talk duration for the agent (5 minutes here)
                      for i in range(agents_split[0])]  # Create the specified number of morning agents

    # Initialize agents for the afternoon shift based on the agents' split configuration
    agents_afternoon = [{'id': i+1 + agents_split[0],    
                         # Set agent responsiveness, higher for peak times if agent split indicates a high volume period in the afternoon
                         'responsiveness': min(1, 0.97 + np.random.exponential(scale=0.01)) if agents_split == [15,5] else min(1, 0.93 + np.random.exponential(scale=0.01)),
                         'available_until': start_time,  # When the agent becomes available (start of the day)
                         'talk_duration_lambda': 6*60}  # Average talk duration for the agent (6 minutes here)
                        for i in range(agents_split[1])]  # Create the specified number of afternoon agents

    # Main simulation loop
    while current_time <= end_time:
        # Define the end of the current day's working hours
        end_of_day = datetime(current_time.year, current_time.month, current_time.day, 16, 0)
        # Generate call logs for the current day
        call_logs.extend([call for customer in customers for call in simulate_calls_for_customer_nhpp(customer, current_time, end_of_day, high_volume_period)])

        # Determine active agents based on the current time of day
        if 8 <= current_time.hour < 12:
            active_agents = agents_morning
        else:
            active_agents = agents_afternoon        

        # Process each call in the call logs
        for call in sorted(call_logs, key=lambda x: x['call_time']):
            # Find agents that are available to take the call
            available_agents = sorted([agent for agent in active_agents if agent['available_until'] <= call['call_time']], key=lambda x: x['available_until'])
            # If no agents are available or the agent doesn't answer, log the call as abandoned
            if not available_agents or random.random() > available_agents[0]['responsiveness']:
                answered_calls.append({'customer_id': call['customer_id'], 'call_time': call['call_time'], 'status': 'abandoned', 'agent_id': 'NA', 'call_duration': '00:00', 'wait_time': timedelta(seconds=0)})
                continue
            # Select the first available agent to handle the call
            agent = available_agents[0]
            # Calculate the wait time for the call
            wait_time = min(call['tolerance'], call['call_time'] - agent['available_until'])
            # Simulate the call duration
            call_duration_seconds = truncated_exponential_with_outlier_inverse(4*60)
            # Update the agent's next available time based on the call duration
            agent['available_until'] = call['call_time'] + timedelta(seconds=call_duration_seconds)
            # Log the answered call with the relevant details
            answered_calls.append({'customer_id': call['customer_id'], 'call_time': call['call_time'], 'status': 'answered', 'agent_id': agent['id'], 'call_duration': timedelta(seconds=call_duration_seconds), 'wait_time': wait_time})
            # Collect wait time for analysis
            wait_times.append(wait_time)

        # Calculate and store the average wait time for the current day
        if wait_times:  # Check if there are any wait times to avoid division by zero
            daily_avg_wait_time_for_current_day = np.mean(wait_times)
            daily_avg_wait_times.append(daily_avg_wait_time_for_current_day)
            wait_times.clear()  # Clear wait times for the next day
        else:
            daily_avg_wait_times.append(0)

        # Clear call logs for the next day
        call_logs.clear()
        # Move to the next day at the start of working hours
        current_time += timedelta(days=1)
        current_time = datetime(current_time.year, current_time.month, current_time.day, 8, 0)

    # Compute the overall average wait time across all days
    overall_avg_wait_time = np.mean(daily_avg_wait_times)
    # Compute the answer rate for the run
    answer_rate_run = len([call for call in answered_calls if call['status'] == 'answered']) / len(answered_calls)

    # Return the simulation results as a dictionary
    return {
        'average_wait_time': overall_avg_wait_time,
        'answer_rate': answer_rate_run,
        'answered_calls': answered_calls
    }

# %%
# Define scenarios
scenarios = {
    "High volume in morning & constant availability": ("morning", [10, 10]),
    "High volume in afternoon & constant availability": ("afternoon", [10, 10]),
    "High volume in morning & higher availability in morning": ("morning", [5, 15]),
    "High volume in afternoon & higher availability in afternoon": ("afternoon", [5, 15])
}

# Number of desired runs for each scenario
num_runs = 1000

# Store results for all scenarios
all_results = {}

for name, (period, split) in scenarios.items():
    results_for_scenario = []
    for run in range(num_runs):
        result = optimized_simulation(run, period, split)
        results_for_scenario.append(result)

        # Print the results for immediate feedback
        print(f"Scenario: {name}, Simulation {run + 1}:")
        print(f"    Average wait time: {result['average_wait_time'].total_seconds()/60:.2f} minutes")
        print(f"    Answer rate: {result['answer_rate']*100:.2f}%")
        print("")

    all_results[name] = results_for_scenario
# Out:
# Scenario: High volume in morning & constant availability, Simulation 1:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.78%
#
# Scenario: High volume in morning & constant availability, Simulation 2:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.85%
#
# Scenario: High volume in morning & constant availability, Simulation 3:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.44%
#
# Scenario: High volume in morning & constant availability, Simulation 4:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.81%
#
# Scenario: High volume in morning & constant availability, Simulation 5:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.14%
#
# Scenario: High volume in morning & constant availability, Simulation 6:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.00%
#
# Scenario: High volume in morning & constant availability, Simulation 7:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 8:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.81%
#
# Scenario: High volume in morning & constant availability, Simulation 9:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.57%
#
# Scenario: High volume in morning & constant availability, Simulation 10:
#     Average wait time: 4.99 minutes
#     Answer rate: 95.00%
#
# Scenario: High volume in morning & constant availability, Simulation 11:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.05%
#
# Scenario: High volume in morning & constant availability, Simulation 12:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.64%
#
# Scenario: High volume in morning & constant availability, Simulation 13:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.03%
#
# Scenario: High volume in morning & constant availability, Simulation 14:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.09%
#
# Scenario: High volume in morning & constant availability, Simulation 15:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 16:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.70%
#
# Scenario: High volume in morning & constant availability, Simulation 17:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.78%
#
# Scenario: High volume in morning & constant availability, Simulation 18:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.86%
#
# Scenario: High volume in morning & constant availability, Simulation 19:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.44%
#
# Scenario: High volume in morning & constant availability, Simulation 20:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.82%
#
# Scenario: High volume in morning & constant availability, Simulation 21:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 22:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.63%
#
# Scenario: High volume in morning & constant availability, Simulation 23:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.76%
#
# Scenario: High volume in morning & constant availability, Simulation 24:
#     Average wait time: 5.06 minutes
#     Answer rate: 94.20%
#
# Scenario: High volume in morning & constant availability, Simulation 25:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.43%
#
# Scenario: High volume in morning & constant availability, Simulation 26:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.77%
#
# Scenario: High volume in morning & constant availability, Simulation 27:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.40%
#
# Scenario: High volume in morning & constant availability, Simulation 28:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.98%
#
# Scenario: High volume in morning & constant availability, Simulation 29:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.38%
#
# Scenario: High volume in morning & constant availability, Simulation 30:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.27%
#
# Scenario: High volume in morning & constant availability, Simulation 31:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.22%
#
# Scenario: High volume in morning & constant availability, Simulation 32:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.24%
#
# Scenario: High volume in morning & constant availability, Simulation 33:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.61%
#
# Scenario: High volume in morning & constant availability, Simulation 34:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.50%
#
# Scenario: High volume in morning & constant availability, Simulation 35:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 36:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.73%
#
# Scenario: High volume in morning & constant availability, Simulation 37:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.83%
#
# Scenario: High volume in morning & constant availability, Simulation 38:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.35%
#
# Scenario: High volume in morning & constant availability, Simulation 39:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.42%
#
# Scenario: High volume in morning & constant availability, Simulation 40:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.51%
#
# Scenario: High volume in morning & constant availability, Simulation 41:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 42:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.61%
#
# Scenario: High volume in morning & constant availability, Simulation 43:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.45%
#
# Scenario: High volume in morning & constant availability, Simulation 44:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 45:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.66%
#
# Scenario: High volume in morning & constant availability, Simulation 46:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 47:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.86%
#
# Scenario: High volume in morning & constant availability, Simulation 48:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.80%
#
# Scenario: High volume in morning & constant availability, Simulation 49:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.10%
#
# Scenario: High volume in morning & constant availability, Simulation 50:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 51:
#     Average wait time: 4.96 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 52:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.88%
#
# Scenario: High volume in morning & constant availability, Simulation 53:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.34%
#
# Scenario: High volume in morning & constant availability, Simulation 54:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 55:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.14%
#
# Scenario: High volume in morning & constant availability, Simulation 56:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.16%
#
# Scenario: High volume in morning & constant availability, Simulation 57:
#     Average wait time: 5.05 minutes
#     Answer rate: 94.18%
#
# Scenario: High volume in morning & constant availability, Simulation 58:
#     Average wait time: 5.07 minutes
#     Answer rate: 94.65%
#
# Scenario: High volume in morning & constant availability, Simulation 59:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.83%
#
# Scenario: High volume in morning & constant availability, Simulation 60:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.87%
#
# Scenario: High volume in morning & constant availability, Simulation 61:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.38%
#
# Scenario: High volume in morning & constant availability, Simulation 62:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.06%
# Scenario: High volume in morning & constant availability, Simulation 63:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.24%
#
# Scenario: High volume in morning & constant availability, Simulation 64:
#     Average wait time: 5.06 minutes
#     Answer rate: 94.09%
#
# Scenario: High volume in morning & constant availability, Simulation 65:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.68%
#
# Scenario: High volume in morning & constant availability, Simulation 66:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.38%
#
# Scenario: High volume in morning & constant availability, Simulation 67:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.68%
#
# Scenario: High volume in morning & constant availability, Simulation 68:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.43%
#
# Scenario: High volume in morning & constant availability, Simulation 69:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.93%
#
# Scenario: High volume in morning & constant availability, Simulation 70:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 71:
#     Average wait time: 5.07 minutes
#     Answer rate: 94.38%
#
# Scenario: High volume in morning & constant availability, Simulation 72:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.28%
#
# Scenario: High volume in morning & constant availability, Simulation 73:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.32%
#
# Scenario: High volume in morning & constant availability, Simulation 74:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.54%
#
# Scenario: High volume in morning & constant availability, Simulation 75:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in morning & constant availability, Simulation 76:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.10%
#
# Scenario: High volume in morning & constant availability, Simulation 77:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.21%
#
# Scenario: High volume in morning & constant availability, Simulation 78:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.27%
#
# Scenario: High volume in morning & constant availability, Simulation 79:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.75%
#
# Scenario: High volume in morning & constant availability, Simulation 80:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 81:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 82:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.30%
#
# Scenario: High volume in morning & constant availability, Simulation 83:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.47%
#
# Scenario: High volume in morning & constant availability, Simulation 84:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 85:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.23%
#
# Scenario: High volume in morning & constant availability, Simulation 86:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.31%
#
# Scenario: High volume in morning & constant availability, Simulation 87:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.65%
#
# Scenario: High volume in morning & constant availability, Simulation 88:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.73%
#
# Scenario: High volume in morning & constant availability, Simulation 89:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.08%
#
# Scenario: High volume in morning & constant availability, Simulation 90:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.26%
#
# Scenario: High volume in morning & constant availability, Simulation 91:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.48%
#
# Scenario: High volume in morning & constant availability, Simulation 92:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.36%
#
# Scenario: High volume in morning & constant availability, Simulation 93:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.17%
#
# Scenario: High volume in morning & constant availability, Simulation 94:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.61%
#
# Scenario: High volume in morning & constant availability, Simulation 95:
#     Average wait time: 5.01 minutes
#     Answer rate: 95.15%
#
# Scenario: High volume in morning & constant availability, Simulation 96:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.88%
#
# Scenario: High volume in morning & constant availability, Simulation 97:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.38%
#
# Scenario: High volume in morning & constant availability, Simulation 98:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 99:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.19%
#
# Scenario: High volume in morning & constant availability, Simulation 100:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.06%
#
# Scenario: High volume in morning & constant availability, Simulation 101:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 102:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 103:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.95%
#
# Scenario: High volume in morning & constant availability, Simulation 104:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.87%
#
# Scenario: High volume in morning & constant availability, Simulation 105:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.85%
#
# Scenario: High volume in morning & constant availability, Simulation 106:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.54%
#
# Scenario: High volume in morning & constant availability, Simulation 107:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.02%
#
# Scenario: High volume in morning & constant availability, Simulation 108:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.26%
#
# Scenario: High volume in morning & constant availability, Simulation 109:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.15%
#
# Scenario: High volume in morning & constant availability, Simulation 110:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 111:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.11%
#
# Scenario: High volume in morning & constant availability, Simulation 112:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.98%
#
# Scenario: High volume in morning & constant availability, Simulation 113:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.11%
#
# Scenario: High volume in morning & constant availability, Simulation 114:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.10%
#
# Scenario: High volume in morning & constant availability, Simulation 115:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.37%
#
# Scenario: High volume in morning & constant availability, Simulation 116:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 117:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 118:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.86%
#
# Scenario: High volume in morning & constant availability, Simulation 119:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 120:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.34%
#
# Scenario: High volume in morning & constant availability, Simulation 121:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.39%
#
# Scenario: High volume in morning & constant availability, Simulation 122:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.96%
#
# Scenario: High volume in morning & constant availability, Simulation 123:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.80%
# Scenario: High volume in morning & constant availability, Simulation 124:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 125:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.30%
#
# Scenario: High volume in morning & constant availability, Simulation 126:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.77%
#
# Scenario: High volume in morning & constant availability, Simulation 127:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.08%
#
# Scenario: High volume in morning & constant availability, Simulation 128:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.54%
#
# Scenario: High volume in morning & constant availability, Simulation 129:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 130:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 131:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.34%
#
# Scenario: High volume in morning & constant availability, Simulation 132:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 133:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 134:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.31%
#
# Scenario: High volume in morning & constant availability, Simulation 135:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.67%
#
# Scenario: High volume in morning & constant availability, Simulation 136:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.34%
#
# Scenario: High volume in morning & constant availability, Simulation 137:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.87%
#
# Scenario: High volume in morning & constant availability, Simulation 138:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.19%
#
# Scenario: High volume in morning & constant availability, Simulation 139:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.26%
#
# Scenario: High volume in morning & constant availability, Simulation 140:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.32%
#
# Scenario: High volume in morning & constant availability, Simulation 141:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.45%
#
# Scenario: High volume in morning & constant availability, Simulation 142:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.59%
#
# Scenario: High volume in morning & constant availability, Simulation 143:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.38%
#
# Scenario: High volume in morning & constant availability, Simulation 144:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.28%
#
# Scenario: High volume in morning & constant availability, Simulation 145:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in morning & constant availability, Simulation 146:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.90%
#
# Scenario: High volume in morning & constant availability, Simulation 147:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.63%
#
# Scenario: High volume in morning & constant availability, Simulation 148:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.98%
#
# Scenario: High volume in morning & constant availability, Simulation 149:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.76%
#
# Scenario: High volume in morning & constant availability, Simulation 150:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 151:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.19%
#
# Scenario: High volume in morning & constant availability, Simulation 152:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.75%
#
# Scenario: High volume in morning & constant availability, Simulation 153:
#     Average wait time: 5.07 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 154:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.71%
#
# Scenario: High volume in morning & constant availability, Simulation 155:
#     Average wait time: 5.06 minutes
#     Answer rate: 94.35%
#
# Scenario: High volume in morning & constant availability, Simulation 156:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.21%
#
# Scenario: High volume in morning & constant availability, Simulation 157:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.41%
#
# Scenario: High volume in morning & constant availability, Simulation 158:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 159:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.35%
#
# Scenario: High volume in morning & constant availability, Simulation 160:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.55%
#
# Scenario: High volume in morning & constant availability, Simulation 161:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.15%
#
# Scenario: High volume in morning & constant availability, Simulation 162:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.53%
#
# Scenario: High volume in morning & constant availability, Simulation 163:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.15%
#
# Scenario: High volume in morning & constant availability, Simulation 164:
#     Average wait time: 5.05 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 165:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.95%
#
# Scenario: High volume in morning & constant availability, Simulation 166:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.05%
#
# Scenario: High volume in morning & constant availability, Simulation 167:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.52%
#
# Scenario: High volume in morning & constant availability, Simulation 168:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.27%
#
# Scenario: High volume in morning & constant availability, Simulation 169:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.10%
#
# Scenario: High volume in morning & constant availability, Simulation 170:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 171:
#     Average wait time: 5.06 minutes
#     Answer rate: 94.18%
#
# Scenario: High volume in morning & constant availability, Simulation 172:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 173:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in morning & constant availability, Simulation 174:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.42%
#
# Scenario: High volume in morning & constant availability, Simulation 175:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.21%
#
# Scenario: High volume in morning & constant availability, Simulation 176:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 177:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.88%
#
# Scenario: High volume in morning & constant availability, Simulation 178:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.42%
#
# Scenario: High volume in morning & constant availability, Simulation 179:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.16%
#
# Scenario: High volume in morning & constant availability, Simulation 180:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.46%
#
# Scenario: High volume in morning & constant availability, Simulation 181:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.89%
#
# Scenario: High volume in morning & constant availability, Simulation 182:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 183:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 184:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.17%
# Scenario: High volume in morning & constant availability, Simulation 185:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.13%
#
# Scenario: High volume in morning & constant availability, Simulation 186:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.23%
#
# Scenario: High volume in morning & constant availability, Simulation 187:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.61%
#
# Scenario: High volume in morning & constant availability, Simulation 188:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 189:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.84%
#
# Scenario: High volume in morning & constant availability, Simulation 190:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.03%
#
# Scenario: High volume in morning & constant availability, Simulation 191:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.90%
#
# Scenario: High volume in morning & constant availability, Simulation 192:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.93%
#
# Scenario: High volume in morning & constant availability, Simulation 193:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.76%
#
# Scenario: High volume in morning & constant availability, Simulation 194:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.87%
#
# Scenario: High volume in morning & constant availability, Simulation 195:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.27%
#
# Scenario: High volume in morning & constant availability, Simulation 196:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.08%
#
# Scenario: High volume in morning & constant availability, Simulation 197:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.81%
#
# Scenario: High volume in morning & constant availability, Simulation 198:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.05%
#
# Scenario: High volume in morning & constant availability, Simulation 199:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.29%
#
# Scenario: High volume in morning & constant availability, Simulation 200:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.22%
#
# Scenario: High volume in morning & constant availability, Simulation 201:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.62%
#
# Scenario: High volume in morning & constant availability, Simulation 202:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.48%
#
# Scenario: High volume in morning & constant availability, Simulation 203:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.63%
#
# Scenario: High volume in morning & constant availability, Simulation 204:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.82%
#
# Scenario: High volume in morning & constant availability, Simulation 205:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.82%
#
# Scenario: High volume in morning & constant availability, Simulation 206:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.49%
#
# Scenario: High volume in morning & constant availability, Simulation 207:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.60%
#
# Scenario: High volume in morning & constant availability, Simulation 208:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.57%
#
# Scenario: High volume in morning & constant availability, Simulation 209:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.46%
#
# Scenario: High volume in morning & constant availability, Simulation 210:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.30%
#
# Scenario: High volume in morning & constant availability, Simulation 211:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.79%
#
# Scenario: High volume in morning & constant availability, Simulation 212:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.05%
#
# Scenario: High volume in morning & constant availability, Simulation 213:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 214:
#     Average wait time: 5.05 minutes
#     Answer rate: 94.39%
#
# Scenario: High volume in morning & constant availability, Simulation 215:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.92%
#
# Scenario: High volume in morning & constant availability, Simulation 216:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.16%
#
# Scenario: High volume in morning & constant availability, Simulation 217:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.68%
#
# Scenario: High volume in morning & constant availability, Simulation 218:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.15%
#
# Scenario: High volume in morning & constant availability, Simulation 219:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 220:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.55%
#
# Scenario: High volume in morning & constant availability, Simulation 221:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.54%
#
# Scenario: High volume in morning & constant availability, Simulation 222:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.86%
#
# Scenario: High volume in morning & constant availability, Simulation 223:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.06%
#
# Scenario: High volume in morning & constant availability, Simulation 224:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.05%
#
# Scenario: High volume in morning & constant availability, Simulation 225:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.59%
#
# Scenario: High volume in morning & constant availability, Simulation 226:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.52%
#
# Scenario: High volume in morning & constant availability, Simulation 227:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.93%
#
# Scenario: High volume in morning & constant availability, Simulation 228:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.06%
#
# Scenario: High volume in morning & constant availability, Simulation 229:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 230:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.72%
#
# Scenario: High volume in morning & constant availability, Simulation 231:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.19%
#
# Scenario: High volume in morning & constant availability, Simulation 232:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.65%
#
# Scenario: High volume in morning & constant availability, Simulation 233:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.41%
#
# Scenario: High volume in morning & constant availability, Simulation 234:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 235:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 236:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.95%
#
# Scenario: High volume in morning & constant availability, Simulation 237:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 238:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.72%
#
# Scenario: High volume in morning & constant availability, Simulation 239:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.49%
#
# Scenario: High volume in morning & constant availability, Simulation 240:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.67%
#
# Scenario: High volume in morning & constant availability, Simulation 241:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.97%
#
# Scenario: High volume in morning & constant availability, Simulation 242:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.09%
#
# Scenario: High volume in morning & constant availability, Simulation 243:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.68%
#
# Scenario: High volume in morning & constant availability, Simulation 244:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.25%
#
# Scenario: High volume in morning & constant availability, Simulation 245:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.00%
# Scenario: High volume in morning & constant availability, Simulation 246:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.26%
#
# Scenario: High volume in morning & constant availability, Simulation 247:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.64%
#
# Scenario: High volume in morning & constant availability, Simulation 248:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.86%
#
# Scenario: High volume in morning & constant availability, Simulation 249:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.65%
#
# Scenario: High volume in morning & constant availability, Simulation 250:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.14%
#
# Scenario: High volume in morning & constant availability, Simulation 251:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.20%
#
# Scenario: High volume in morning & constant availability, Simulation 252:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.87%
#
# Scenario: High volume in morning & constant availability, Simulation 253:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.80%
#
# Scenario: High volume in morning & constant availability, Simulation 254:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.75%
#
# Scenario: High volume in morning & constant availability, Simulation 255:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.67%
#
# Scenario: High volume in morning & constant availability, Simulation 256:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 257:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.49%
#
# Scenario: High volume in morning & constant availability, Simulation 258:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.84%
#
# Scenario: High volume in morning & constant availability, Simulation 259:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.28%
#
# Scenario: High volume in morning & constant availability, Simulation 260:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.04%
#
# Scenario: High volume in morning & constant availability, Simulation 261:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 262:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.50%
#
# Scenario: High volume in morning & constant availability, Simulation 263:
#     Average wait time: 5.07 minutes
#     Answer rate: 94.01%
#
# Scenario: High volume in morning & constant availability, Simulation 264:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.59%
#
# Scenario: High volume in morning & constant availability, Simulation 265:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.70%
#
# Scenario: High volume in morning & constant availability, Simulation 266:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.31%
#
# Scenario: High volume in morning & constant availability, Simulation 267:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.30%
#
# Scenario: High volume in morning & constant availability, Simulation 268:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.62%
#
# Scenario: High volume in morning & constant availability, Simulation 269:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.84%
#
# Scenario: High volume in morning & constant availability, Simulation 270:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.53%
#
# Scenario: High volume in morning & constant availability, Simulation 271:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.25%
#
# Scenario: High volume in morning & constant availability, Simulation 272:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.00%
#
# Scenario: High volume in morning & constant availability, Simulation 273:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.27%
#
# Scenario: High volume in morning & constant availability, Simulation 274:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.33%
#
# Scenario: High volume in morning & constant availability, Simulation 275:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.60%
#
# Scenario: High volume in morning & constant availability, Simulation 276:
#     Average wait time: 4.98 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 277:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.72%
#
# Scenario: High volume in morning & constant availability, Simulation 278:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.76%
#
# Scenario: High volume in morning & constant availability, Simulation 279:
#     Average wait time: 5.03 minutes
#     Answer rate: 95.13%
#
# Scenario: High volume in morning & constant availability, Simulation 280:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.56%
#
# Scenario: High volume in morning & constant availability, Simulation 281:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.48%
#
# Scenario: High volume in morning & constant availability, Simulation 282:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.48%
#
# Scenario: High volume in morning & constant availability, Simulation 283:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 284:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.83%
#
# Scenario: High volume in morning & constant availability, Simulation 285:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.28%
#
# Scenario: High volume in morning & constant availability, Simulation 286:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.33%
#
# Scenario: High volume in morning & constant availability, Simulation 287:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.88%
#
# Scenario: High volume in morning & constant availability, Simulation 288:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.10%
#
# Scenario: High volume in morning & constant availability, Simulation 289:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 290:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.67%
#
# Scenario: High volume in morning & constant availability, Simulation 291:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.33%
#
# Scenario: High volume in morning & constant availability, Simulation 292:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.72%
#
# Scenario: High volume in morning & constant availability, Simulation 293:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.02%
#
# Scenario: High volume in morning & constant availability, Simulation 294:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.11%
#
# Scenario: High volume in morning & constant availability, Simulation 295:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.44%
#
# Scenario: High volume in morning & constant availability, Simulation 296:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 297:
#     Average wait time: 5.04 minutes
#     Answer rate: 93.54%
#
# Scenario: High volume in morning & constant availability, Simulation 298:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.61%
#
# Scenario: High volume in morning & constant availability, Simulation 299:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.44%
#
# Scenario: High volume in morning & constant availability, Simulation 300:
#     Average wait time: 5.05 minutes
#     Answer rate: 93.78%
#
# Scenario: High volume in morning & constant availability, Simulation 301:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.01%
#
# Scenario: High volume in morning & constant availability, Simulation 302:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.96%
#
# Scenario: High volume in morning & constant availability, Simulation 303:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.23%
#
# Scenario: High volume in morning & constant availability, Simulation 304:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.83%
#
# Scenario: High volume in morning & constant availability, Simulation 305:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 306:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.90%
# Scenario: High volume in morning & constant availability, Simulation 307:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 308:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.87%
#
# Scenario: High volume in morning & constant availability, Simulation 309:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.79%
#
# Scenario: High volume in morning & constant availability, Simulation 310:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.52%
#
# Scenario: High volume in morning & constant availability, Simulation 311:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 312:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.95%
#
# Scenario: High volume in morning & constant availability, Simulation 313:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.15%
#
# Scenario: High volume in morning & constant availability, Simulation 314:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.33%
#
# Scenario: High volume in morning & constant availability, Simulation 315:
#     Average wait time: 5.02 minutes
#     Answer rate: 92.88%
#
# Scenario: High volume in morning & constant availability, Simulation 316:
#     Average wait time: 5.06 minutes
#     Answer rate: 93.60%
#
# Scenario: High volume in morning & constant availability, Simulation 317:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.43%
#
# Scenario: High volume in morning & constant availability, Simulation 318:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.71%
#
# Scenario: High volume in morning & constant availability, Simulation 319:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.47%
#
# Scenario: High volume in morning & constant availability, Simulation 320:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 321:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.66%
#
# Scenario: High volume in morning & constant availability, Simulation 322:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.22%
#
# Scenario: High volume in morning & constant availability, Simulation 323:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.57%
#
# Scenario: High volume in morning & constant availability, Simulation 324:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 325:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.72%
#
# Scenario: High volume in morning & constant availability, Simulation 326:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.23%
#
# Scenario: High volume in morning & constant availability, Simulation 327:
#     Average wait time: 4.95 minutes
#     Answer rate: 93.81%
#
# Scenario: High volume in morning & constant availability, Simulation 328:
#     Average wait time: 5.03 minutes
#     Answer rate: 94.35%
#
# Scenario: High volume in morning & constant availability, Simulation 329:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 330:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.03%
#
# Scenario: High volume in morning & constant availability, Simulation 331:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.07%
#
# Scenario: High volume in morning & constant availability, Simulation 332:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.26%
#
# Scenario: High volume in morning & constant availability, Simulation 333:
#     Average wait time: 5.00 minutes
#     Answer rate: 94.40%
#
# Scenario: High volume in morning & constant availability, Simulation 334:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.02%
#
# Scenario: High volume in morning & constant availability, Simulation 335:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.49%
#
# Scenario: High volume in morning & constant availability, Simulation 336:
#     Average wait time: 5.04 minutes
#     Answer rate: 94.13%
#
# Scenario: High volume in morning & constant availability, Simulation 337:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.65%
#
# Scenario: High volume in morning & constant availability, Simulation 338:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.61%
#
# Scenario: High volume in morning & constant availability, Simulation 339:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.51%
#
# Scenario: High volume in morning & constant availability, Simulation 340:
#     Average wait time: 4.99 minutes
#     Answer rate: 93.70%
#
# Scenario: High volume in morning & constant availability, Simulation 341:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.94%
#
# Scenario: High volume in morning & constant availability, Simulation 342:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 343:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.55%
#
# Scenario: High volume in morning & constant availability, Simulation 344:
#     Average wait time: 5.03 minutes
#     Answer rate: 93.61%
#
# Scenario: High volume in morning & constant availability, Simulation 345:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.19%
#
# Scenario: High volume in morning & constant availability, Simulation 346:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.05%
#
# Scenario: High volume in morning & constant availability, Simulation 347:
#     Average wait time: 5.01 minutes
#     Answer rate: 93.91%
#
# Scenario: High volume in morning & constant availability, Simulation 348:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.74%
#
# Scenario: High volume in morning & constant availability, Simulation 349:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.32%
#
# Scenario: High volume in morning & constant availability, Simulation 350:
#     Average wait time: 5.02 minutes
#     Answer rate: 94.25%
#
# Scenario: High volume in morning & constant availability, Simulation 351:
#     Average wait time: 4.99 minutes
#     Answer rate: 94.25%
#
# Scenario: High volume in morning & constant availability, Simulation 352:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.12%
#
# Scenario: High volume in morning & constant availability, Simulation 353:
#     Average wait time: 5.01 minutes
#     Answer rate: 94.01%
#
# Scenario: High volume in morning & constant availability, Simulation 354:
#     Average wait time: 5.00 minutes
#     Answer rate: 93.53%
#
# Scenario: High volume in morning & constant availability, Simulation 355:
#     Average wait time: 4.98 minutes
#     Answer rate: 94.32%
#
# Scenario: High volume in morning & constant availability, Simulation 356:
#     Average wait time: 5.02 minutes
#     Answer rate: 93.65%
#
# ...
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 893:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.16%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 894:
#     Average wait time: 4.55 minutes
#     Answer rate: 94.42%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 895:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.87%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 896:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.13%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 897:
#     Average wait time: 4.55 minutes
#     Answer rate: 95.15%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 898:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.18%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 899:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.17%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 900:
#     Average wait time: 4.63 minutes
#     Answer rate: 94.82%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 901:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.89%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 902:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.53%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 903:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.09%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 904:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.61%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 905:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.02%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 906:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.13%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 907:
#     Average wait time: 4.54 minutes
#     Answer rate: 94.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 908:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.78%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 909:
#     Average wait time: 4.60 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 910:
#     Average wait time: 4.54 minutes
#     Answer rate: 94.54%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 911:
#     Average wait time: 4.61 minutes
#     Answer rate: 95.08%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 912:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.22%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 913:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.42%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 914:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.82%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 915:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.26%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 916:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.98%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 917:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.79%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 918:
#     Average wait time: 4.63 minutes
#     Answer rate: 95.15%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 919:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.12%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 920:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.51%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 921:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.12%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 922:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.09%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 923:
#     Average wait time: 4.62 minutes
#     Answer rate: 94.79%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 924:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.85%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 925:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.35%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 926:
#     Average wait time: 4.61 minutes
#     Answer rate: 95.44%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 927:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.75%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 928:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 929:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.55%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 930:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.40%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 931:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.42%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 932:
#     Average wait time: 4.55 minutes
#     Answer rate: 94.59%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 933:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.89%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 934:
#     Average wait time: 4.56 minutes
#     Answer rate: 94.78%
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 935:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.51%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 936:
#     Average wait time: 4.55 minutes
#     Answer rate: 94.44%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 937:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.24%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 938:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.38%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 939:
#     Average wait time: 4.54 minutes
#     Answer rate: 95.06%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 940:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.08%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 941:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.49%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 942:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.11%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 943:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.47%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 944:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.53%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 945:
#     Average wait time: 4.62 minutes
#     Answer rate: 95.00%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 946:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.28%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 947:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.82%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 948:
#     Average wait time: 4.52 minutes
#     Answer rate: 95.48%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 949:
#     Average wait time: 4.61 minutes
#     Answer rate: 95.30%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 950:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.21%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 951:
#     Average wait time: 4.62 minutes
#     Answer rate: 94.92%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 952:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.29%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 953:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.18%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 954:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.35%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 955:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.97%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 956:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.78%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 957:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.60%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 958:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.77%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 959:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.80%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 960:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.96%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 961:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 962:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.65%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 963:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.45%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 964:
#     Average wait time: 4.54 minutes
#     Answer rate: 94.94%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 965:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.11%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 966:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.53%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 967:
#     Average wait time: 4.55 minutes
#     Answer rate: 95.55%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 968:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.89%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 969:
#     Average wait time: 4.55 minutes
#     Answer rate: 94.70%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 970:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.76%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 971:
#     Average wait time: 4.55 minutes
#     Answer rate: 95.35%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 972:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.04%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 973:
#     Average wait time: 4.56 minutes
#     Answer rate: 94.99%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 974:
#     Average wait time: 4.59 minutes
#     Answer rate: 95.32%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 975:
#     Average wait time: 4.60 minutes
#     Answer rate: 94.68%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 976:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.11%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 977:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.20%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 978:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.22%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 979:
#     Average wait time: 4.55 minutes
#     Answer rate: 95.48%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 980:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 981:
#     Average wait time: 4.51 minutes
#     Answer rate: 94.30%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 982:
#     Average wait time: 4.60 minutes
#     Answer rate: 94.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 983:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 984:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.96%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 985:
#     Average wait time: 4.61 minutes
#     Answer rate: 95.17%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 986:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.51%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 987:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.02%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 988:
#     Average wait time: 4.60 minutes
#     Answer rate: 94.72%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 989:
#     Average wait time: 4.58 minutes
#     Answer rate: 94.46%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 990:
#     Average wait time: 4.61 minutes
#     Answer rate: 94.51%
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 991:
#     Average wait time: 4.58 minutes
#     Answer rate: 95.02%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 992:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.70%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 993:
#     Average wait time: 4.60 minutes
#     Answer rate: 95.19%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 994:
#     Average wait time: 4.57 minutes
#     Answer rate: 94.47%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 995:
#     Average wait time: 4.57 minutes
#     Answer rate: 95.23%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 996:
#     Average wait time: 4.52 minutes
#     Answer rate: 95.31%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 997:
#     Average wait time: 4.59 minutes
#     Answer rate: 94.71%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 998:
#     Average wait time: 4.56 minutes
#     Answer rate: 95.03%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 999:
#     Average wait time: 4.62 minutes
#     Answer rate: 94.70%
#
# Scenario: High volume in afternoon & higher availability in afternoon, Simulation 1000:
#     Average wait time: 4.54 minutes
#     Answer rate: 94.82%

# %%
# Helper function to convert decimal minutes to "minutes:seconds" format
def minutes_to_min_sec(decimal_minutes):
    """
    Convert decimal minutes to "minutes:seconds" format.

    Args:
    - decimal_minutes (float): Time in decimal format.

    Returns:
    - str: Time in "minutes:seconds" format.
    """
    minutes = int(decimal_minutes)  # Extract whole minutes
    seconds = int((decimal_minutes - minutes) * 60)  # Extract remaining seconds
    return f"{minutes}:{seconds:02}"  # Return formatted string

# Analyze the results
analysis = {}

# Iterate through each scenario and its corresponding results
for scenario, results in all_results.items():
    # Extract wait times (in seconds) for all runs
    avg_wait_times = [result['average_wait_time'].total_seconds() for result in results]
    # Extract answer rates for all runs
    avg_answer_rates = [result['answer_rate'] for result in results]

    # Store the average and standard deviation for both metrics in the analysis dictionary
    analysis[scenario] = {
        # Convert average wait time to "minutes:seconds" format
        "Average Wait Time/day": minutes_to_min_sec(np.mean(avg_wait_times)/60),
        # Convert standard deviation of wait time to "minutes:seconds" format
        "Std Dev Wait Time": minutes_to_min_sec(np.std(avg_wait_times)/60),
        # Convert average answer rate to percentage and format as string
        "Average Answer Rate/day": f"{np.mean(avg_answer_rates)*100:.2f}%",
        # Convert standard deviation of answer rate to percentage and format as string
        "Std Dev Answer Rate": f"{np.std(avg_answer_rates)*100:.2f}%"
    }

# Convert the analysis to a pandas DataFrame for a clear tabular representation
import pandas as pd

df = pd.DataFrame(analysis).T
df.head()
# Out:
#                                                    Average Wait Time/day  \
# High volume in morning & constant availability                      5:00
# High volume in afternoon & constant availability                    5:00
# High volume in morning & higher availability in...                  4:35
# High volume in afternoon & higher availability ...                  4:34
#
#                                                    Std Dev Wait Time  \
# High volume in morning & constant availability                  0:01
# High volume in afternoon & constant availability                0:01
# High volume in morning & higher availability in...              0:01
# High volume in afternoon & higher availability ...              0:01
#
#                                                    Average Answer Rate/day  \
# High volume in morning & constant availability                      94.00%
# High volume in afternoon & constant availability                    93.98%
# High volume in morning & higher availability in...                  95.06%
# High volume in afternoon & higher availability ...                  95.07%
#
#                                                    Std Dev Answer Rate
# High volume in morning & constant availability                   0.37%
# High volume in afternoon & constant availability                 0.39%
# High volume in morning & higher availability in...               0.42%
# High volume in afternoon & higher availability ...               0.40%

# %% [markdown]
# #####
